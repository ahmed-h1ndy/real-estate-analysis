# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt

# %%
customers = pd.read_csv(r'data/customers.csv')
customers
# Out:
#      Unnamed: 0 ﻿customerid      entity     name     surname  birth_date  sex  \
# 0             0       C0110  Individual   Kareem         Liu   5/11/1968    F
# 1             1       C0010  Individual  Trystan     Oconnor  11/26/1962    M
# 2             2       C0132  Individual     Kale         Gay    4/7/1959    M
# 3             3       C0137  Individual  Russell       Gross  11/25/1959    M
# 4             4       C0174     Company  Marleez          Co         NaN  NaN
# ..          ...         ...         ...      ...         ...         ...  ...
# 157         157       C0170  Individual     Emmy       Singh   12/3/1979    F
# 158         158       C0138  Individual    Colin      Campos   4/14/1942    M
# 159         159       C0113  Individual     Anya  Stephenson   6/11/1959    F
# 160         160       C0147  Individual   Parker       Poole  11/10/1951    M
# 161         161       C0133  Individual     Ivan      Bright   9/15/1953    M
#
#     country       state     purpose  deal_satisfaction mortgage   source
# 0       USA  California        Home                  4      Yes  Website
# 1       USA  California        Home                  1       No  Website
# 2       USA  California        Home                  4      Yes   Agency
# 3       USA  California        Home                  5       No  Website
# 4      USA   California  Investment                  5       No  Website
# ..      ...         ...         ...                ...      ...      ...
# 157     USA    Virginia  Investment                  3      Yes   Agency
# 158     USA  California        Home                  3       No  Website
# 159     USA  California        Home                  4       No  Website
# 160     USA  California        Home                  5       No  Website
# 161     USA  California        Home                  4       No  Website
#
# [162 rows x 13 columns]

# %%
properties = pd.read_csv(r'data/properties.csv')
properties
# Out:
#      Unnamed: 0   ﻿id  building  date_sale       type  property#     area  \
# 0             0  1030         1  11/1/2005  Apartment         30   743.09
# 1             1  1029         1  10/1/2005  Apartment         29   756.21
# 2             2  2002         2   7/1/2007  Apartment          2   587.28
# 3             3  2031         2  12/1/2007  Apartment         31  1604.75
# 4             4  1049         1  11/1/2004  Apartment         49  1375.45
# ..          ...   ...       ...        ...        ...        ...      ...
# 262         262  5044         5      #NUM!  Apartment         44  1238.58
# 263         263  5047         5      #NUM!  Apartment         47   794.52
# 264         264  5048         5      #NUM!  Apartment         48  1013.27
# 265         265  5050         5      #NUM!  Apartment         50  1074.71
# 266         266  5051         5      #NUM!  Apartment         51   789.25
#
#             price  status customerid
# 0    $246,172.68    Sold      C0028
# 1    $246,331.90    Sold      C0027
# 2    $209,280.91    Sold      C0112
# 3    $452,667.01    Sold      C0160
# 4    $467,083.31    Sold      C0014
# ..            ...     ...        ...
# 262  $322,610.74        -        NaN
# 263  $279,191.26        -        NaN
# 264  $287,996.53        -        NaN
# 265  $365,868.78        -        NaN
# 266  $199,216.40        -        NaN
#
# [267 rows x 10 columns]

# %%
customers.columns
# Out:
# Index(['Unnamed: 0', '﻿customerid', 'entity', 'name', 'surname', 'birth_date',
#        'sex', 'country', 'state', 'purpose', 'deal_satisfaction', 'mortgage',
#        'source'],
#       dtype='object')

# %%
properties.columns
# Out:
# Index(['Unnamed: 0', '﻿id', 'building', 'date_sale', 'type', 'property#',
#        'area', 'price', 'status', 'customerid'],
#       dtype='object')

# %%
# Renaming the customerid column as it has an issue in excel
customers = customers.rename(columns = {customers.columns[1]: 'customerid'})
properties = properties.rename(columns = {properties.columns[9]: 'customerid'})
customers['customerid'] = customers['customerid'].astype(str)
properties['customerid'] = properties['customerid'].astype(str)

# %%
customers.dtypes
# Out:
# Unnamed: 0            int64
# customerid           object
# entity               object
# name                 object
# surname              object
# birth_date           object
# sex                  object
# country              object
# state                object
# purpose              object
# deal_satisfaction     int64
# mortgage             object
# source               object
# dtype: object

# %%
properties.dtypes
# Out:
# Unnamed: 0      int64
# ﻿id             int64
# building        int64
# date_sale      object
# type           object
# property#       int64
# area          float64
# price          object
# status         object
# customerid     object
# dtype: object

# %%
# Remove extra spaces to allow merging both data frames
customers['customerid'] = customers['customerid'].str.strip()
properties['customerid'] = properties['customerid'].str.strip()

# %%
# we have to do a 'right' join to keep unsold apartments data
merged_data = pd.merge(customers, properties, on = 'customerid', how = 'right')
merged_data
# Out:
#      Unnamed: 0_x customerid      entity        name   surname  birth_date  \
# 0           140.0      C0028  Individual     Madalyn    Mercer   6/21/1986
# 1           152.0      C0027  Individual        Lara  Carrillo   2/24/1983
# 2            70.0      C0112  Individual     Donavan   Flowers  12/27/1985
# 3            95.0      C0160  Individual      Darien    Dorsey  12/27/1985
# 4            86.0      C0014  Individual  Alessandra     Perry   5/15/1979
# ..            ...        ...         ...         ...       ...         ...
# 262           NaN        nan         NaN         NaN       NaN         NaN
# 263           NaN        nan         NaN         NaN       NaN         NaN
# 264           NaN        nan         NaN         NaN       NaN         NaN
# 265           NaN        nan         NaN         NaN       NaN         NaN
# 266           NaN        nan         NaN         NaN       NaN         NaN
#
#      sex country       state     purpose  ...   source Unnamed: 0_y   ﻿id  \
# 0      F     USA  California        Home  ...  Website            0  1030
# 1      F     USA  California        Home  ...  Website            1  1029
# 2      M     USA  California        Home  ...   Client            2  2002
# 3      M     USA  California  Investment  ...  Website            3  2031
# 4      F     USA  California        Home  ...   Agency            4  1049
# ..   ...     ...         ...         ...  ...      ...          ...   ...
# 262  NaN     NaN         NaN         NaN  ...      NaN          262  5044
# 263  NaN     NaN         NaN         NaN  ...      NaN          263  5047
# 264  NaN     NaN         NaN         NaN  ...      NaN          264  5048
# 265  NaN     NaN         NaN         NaN  ...      NaN          265  5050
# 266  NaN     NaN         NaN         NaN  ...      NaN          266  5051
#
#      building  date_sale       type property#     area         price  status
# 0           1  11/1/2005  Apartment        30   743.09  $246,172.68    Sold
# 1           1  10/1/2005  Apartment        29   756.21  $246,331.90    Sold
# 2           2   7/1/2007  Apartment         2   587.28  $209,280.91    Sold
# 3           2  12/1/2007  Apartment        31  1604.75  $452,667.01    Sold
# 4           1  11/1/2004  Apartment        49  1375.45  $467,083.31    Sold
# ..        ...        ...        ...       ...      ...           ...     ...
# 262         5      #NUM!  Apartment        44  1238.58  $322,610.74        -
# 263         5      #NUM!  Apartment        47   794.52  $279,191.26        -
# 264         5      #NUM!  Apartment        48  1013.27  $287,996.53        -
# 265         5      #NUM!  Apartment        50  1074.71  $365,868.78        -
# 266         5      #NUM!  Apartment        51   789.25  $199,216.40        -
#
# [267 rows x 22 columns]

# %%
# delete both indexing columns
merged_data.drop('Unnamed: 0_x', axis = 1, inplace = True)
merged_data.drop('Unnamed: 0_y', axis = 1, inplace = True)
merged_data
# Out:
#     customerid      entity        name   surname  birth_date  sex country  \
# 0        C0028  Individual     Madalyn    Mercer   6/21/1986    F     USA
# 1        C0027  Individual        Lara  Carrillo   2/24/1983    F     USA
# 2        C0112  Individual     Donavan   Flowers  12/27/1985    M     USA
# 3        C0160  Individual      Darien    Dorsey  12/27/1985    M     USA
# 4        C0014  Individual  Alessandra     Perry   5/15/1979    F     USA
# ..         ...         ...         ...       ...         ...  ...     ...
# 262        nan         NaN         NaN       NaN         NaN  NaN     NaN
# 263        nan         NaN         NaN       NaN         NaN  NaN     NaN
# 264        nan         NaN         NaN       NaN         NaN  NaN     NaN
# 265        nan         NaN         NaN       NaN         NaN  NaN     NaN
# 266        nan         NaN         NaN       NaN         NaN  NaN     NaN
#
#           state     purpose  deal_satisfaction mortgage   source   ﻿id  \
# 0    California        Home                5.0       No  Website  1030
# 1    California        Home                5.0       No  Website  1029
# 2    California        Home                1.0      Yes   Client  2002
# 3    California  Investment                3.0      Yes  Website  2031
# 4    California        Home                4.0       No   Agency  1049
# ..          ...         ...                ...      ...      ...   ...
# 262         NaN         NaN                NaN      NaN      NaN  5044
# 263         NaN         NaN                NaN      NaN      NaN  5047
# 264         NaN         NaN                NaN      NaN      NaN  5048
# 265         NaN         NaN                NaN      NaN      NaN  5050
# 266         NaN         NaN                NaN      NaN      NaN  5051
#
#      building  date_sale       type  property#     area         price  status
# 0           1  11/1/2005  Apartment         30   743.09  $246,172.68    Sold
# 1           1  10/1/2005  Apartment         29   756.21  $246,331.90    Sold
# 2           2   7/1/2007  Apartment          2   587.28  $209,280.91    Sold
# 3           2  12/1/2007  Apartment         31  1604.75  $452,667.01    Sold
# 4           1  11/1/2004  Apartment         49  1375.45  $467,083.31    Sold
# ..        ...        ...        ...        ...      ...           ...     ...
# 262         5      #NUM!  Apartment         44  1238.58  $322,610.74        -
# 263         5      #NUM!  Apartment         47   794.52  $279,191.26        -
# 264         5      #NUM!  Apartment         48  1013.27  $287,996.53        -
# 265         5      #NUM!  Apartment         50  1074.71  $365,868.78        -
# 266         5      #NUM!  Apartment         51   789.25  $199,216.40        -
#
# [267 rows x 20 columns]

# %%
# replace null status values (which represent non sold apartments)
merged_data.loc[merged_data['status'] == '-', 'status'] = 'Available'
merged_data
# Out:
#     customerid      entity        name   surname  birth_date  sex country  \
# 0        C0028  Individual     Madalyn    Mercer   6/21/1986    F     USA
# 1        C0027  Individual        Lara  Carrillo   2/24/1983    F     USA
# 2        C0112  Individual     Donavan   Flowers  12/27/1985    M     USA
# 3        C0160  Individual      Darien    Dorsey  12/27/1985    M     USA
# 4        C0014  Individual  Alessandra     Perry   5/15/1979    F     USA
# ..         ...         ...         ...       ...         ...  ...     ...
# 262        nan         NaN         NaN       NaN         NaN  NaN     NaN
# 263        nan         NaN         NaN       NaN         NaN  NaN     NaN
# 264        nan         NaN         NaN       NaN         NaN  NaN     NaN
# 265        nan         NaN         NaN       NaN         NaN  NaN     NaN
# 266        nan         NaN         NaN       NaN         NaN  NaN     NaN
#
#           state     purpose  deal_satisfaction mortgage   source   ﻿id  \
# 0    California        Home                5.0       No  Website  1030
# 1    California        Home                5.0       No  Website  1029
# 2    California        Home                1.0      Yes   Client  2002
# 3    California  Investment                3.0      Yes  Website  2031
# 4    California        Home                4.0       No   Agency  1049
# ..          ...         ...                ...      ...      ...   ...
# 262         NaN         NaN                NaN      NaN      NaN  5044
# 263         NaN         NaN                NaN      NaN      NaN  5047
# 264         NaN         NaN                NaN      NaN      NaN  5048
# 265         NaN         NaN                NaN      NaN      NaN  5050
# 266         NaN         NaN                NaN      NaN      NaN  5051
#
#      building  date_sale       type  property#     area         price  \
# 0           1  11/1/2005  Apartment         30   743.09  $246,172.68
# 1           1  10/1/2005  Apartment         29   756.21  $246,331.90
# 2           2   7/1/2007  Apartment          2   587.28  $209,280.91
# 3           2  12/1/2007  Apartment         31  1604.75  $452,667.01
# 4           1  11/1/2004  Apartment         49  1375.45  $467,083.31
# ..        ...        ...        ...        ...      ...           ...
# 262         5      #NUM!  Apartment         44  1238.58  $322,610.74
# 263         5      #NUM!  Apartment         47   794.52  $279,191.26
# 264         5      #NUM!  Apartment         48  1013.27  $287,996.53
# 265         5      #NUM!  Apartment         50  1074.71  $365,868.78
# 266         5      #NUM!  Apartment         51   789.25  $199,216.40
#
#         status
# 0        Sold
# 1        Sold
# 2        Sold
# 3        Sold
# 4        Sold
# ..         ...
# 262  Available
# 263  Available
# 264  Available
# 265  Available
# 266  Available
#
# [267 rows x 20 columns]

# %%
merged_data.isnull().sum()
# Out:
# customerid            0
# entity               72
# name                 72
# surname              72
# birth_date           89
# sex                  89
# country              72
# state                86
# purpose              72
# deal_satisfaction    72
# mortgage             72
# source               72
# ﻿id                   0
# building              0
# date_sale             0
# type                  0
# property#             0
# area                  0
# price                 0
# status                0
# dtype: int64

# %%
# handling text missing values
merged_data.loc[merged_data['entity'].isnull(), 'entity'] = None
merged_data.loc[merged_data['name'].isnull(), 'name'] = None
merged_data.loc[merged_data['surname'].isnull(), 'surname'] = None
merged_data.loc[merged_data['sex'].isnull(), 'sex'] = None
merged_data.loc[merged_data['country'].isnull(), 'country'] = None
merged_data.loc[merged_data['state'].isnull(), 'state'] = None
merged_data.loc[merged_data['purpose'].isnull(), 'purpose'] = None
merged_data.loc[merged_data['mortgage'].isnull(), 'mortgage'] = None
merged_data.loc[merged_data['source'].isnull(), 'source'] = None

# %%
merged_data
# Out:
#     customerid      entity        name   surname  birth_date   sex country  \
# 0        C0028  Individual     Madalyn    Mercer   6/21/1986     F     USA
# 1        C0027  Individual        Lara  Carrillo   2/24/1983     F     USA
# 2        C0112  Individual     Donavan   Flowers  12/27/1985     M     USA
# 3        C0160  Individual      Darien    Dorsey  12/27/1985     M     USA
# 4        C0014  Individual  Alessandra     Perry   5/15/1979     F     USA
# ..         ...         ...         ...       ...         ...   ...     ...
# 262        nan        None        None      None         NaN  None    None
# 263        nan        None        None      None         NaN  None    None
# 264        nan        None        None      None         NaN  None    None
# 265        nan        None        None      None         NaN  None    None
# 266        nan        None        None      None         NaN  None    None
#
#           state     purpose  deal_satisfaction mortgage   source   ﻿id  \
# 0    California        Home                5.0       No  Website  1030
# 1    California        Home                5.0       No  Website  1029
# 2    California        Home                1.0      Yes   Client  2002
# 3    California  Investment                3.0      Yes  Website  2031
# 4    California        Home                4.0       No   Agency  1049
# ..          ...         ...                ...      ...      ...   ...
# 262        None        None                NaN     None     None  5044
# 263        None        None                NaN     None     None  5047
# 264        None        None                NaN     None     None  5048
# 265        None        None                NaN     None     None  5050
# 266        None        None                NaN     None     None  5051
#
#      building  date_sale       type  property#     area         price  \
# 0           1  11/1/2005  Apartment         30   743.09  $246,172.68
# 1           1  10/1/2005  Apartment         29   756.21  $246,331.90
# 2           2   7/1/2007  Apartment          2   587.28  $209,280.91
# 3           2  12/1/2007  Apartment         31  1604.75  $452,667.01
# 4           1  11/1/2004  Apartment         49  1375.45  $467,083.31
# ..        ...        ...        ...        ...      ...           ...
# 262         5      #NUM!  Apartment         44  1238.58  $322,610.74
# 263         5      #NUM!  Apartment         47   794.52  $279,191.26
# 264         5      #NUM!  Apartment         48  1013.27  $287,996.53
# 265         5      #NUM!  Apartment         50  1074.71  $365,868.78
# 266         5      #NUM!  Apartment         51   789.25  $199,216.40
#
#         status
# 0        Sold
# 1        Sold
# 2        Sold
# 3        Sold
# 4        Sold
# ..         ...
# 262  Available
# 263  Available
# 264  Available
# 265  Available
# 266  Available
#
# [267 rows x 20 columns]

# %%
merged_data.isnull().sum()
# Out:
# customerid            0
# entity               72
# name                 72
# surname              72
# birth_date           89
# sex                  89
# country              72
# state                86
# purpose              72
# deal_satisfaction    72
# mortgage             72
# source               72
# ﻿id                   0
# building              0
# date_sale             0
# type                  0
# property#             0
# area                  0
# price                 0
# status                0
# dtype: int64

# %%
# handling missing date values
merged_data['date_sale'] = pd.to_datetime(merged_data['date_sale'], errors = 'coerce')
merged_data['birth_date'] = pd.to_datetime(merged_data['birth_date'], errors = 'coerce')
merged_data
# Out:
#     customerid      entity        name   surname birth_date   sex country  \
# 0        C0028  Individual     Madalyn    Mercer 1986-06-21     F     USA
# 1        C0027  Individual        Lara  Carrillo 1983-02-24     F     USA
# 2        C0112  Individual     Donavan   Flowers 1985-12-27     M     USA
# 3        C0160  Individual      Darien    Dorsey 1985-12-27     M     USA
# 4        C0014  Individual  Alessandra     Perry 1979-05-15     F     USA
# ..         ...         ...         ...       ...        ...   ...     ...
# 262        nan        None        None      None        NaT  None    None
# 263        nan        None        None      None        NaT  None    None
# 264        nan        None        None      None        NaT  None    None
# 265        nan        None        None      None        NaT  None    None
# 266        nan        None        None      None        NaT  None    None
#
#           state     purpose  deal_satisfaction mortgage   source   ﻿id  \
# 0    California        Home                5.0       No  Website  1030
# 1    California        Home                5.0       No  Website  1029
# 2    California        Home                1.0      Yes   Client  2002
# 3    California  Investment                3.0      Yes  Website  2031
# 4    California        Home                4.0       No   Agency  1049
# ..          ...         ...                ...      ...      ...   ...
# 262        None        None                NaN     None     None  5044
# 263        None        None                NaN     None     None  5047
# 264        None        None                NaN     None     None  5048
# 265        None        None                NaN     None     None  5050
# 266        None        None                NaN     None     None  5051
#
#      building  date_sale       type  property#     area         price  \
# 0           1 2005-11-01  Apartment         30   743.09  $246,172.68
# 1           1 2005-10-01  Apartment         29   756.21  $246,331.90
# 2           2 2007-07-01  Apartment          2   587.28  $209,280.91
# 3           2 2007-12-01  Apartment         31  1604.75  $452,667.01
# 4           1 2004-11-01  Apartment         49  1375.45  $467,083.31
# ..        ...        ...        ...        ...      ...           ...
# 262         5        NaT  Apartment         44  1238.58  $322,610.74
# 263         5        NaT  Apartment         47   794.52  $279,191.26
# 264         5        NaT  Apartment         48  1013.27  $287,996.53
# 265         5        NaT  Apartment         50  1074.71  $365,868.78
# 266         5        NaT  Apartment         51   789.25  $199,216.40
#
#         status
# 0        Sold
# 1        Sold
# 2        Sold
# 3        Sold
# 4        Sold
# ..         ...
# 262  Available
# 263  Available
# 264  Available
# 265  Available
# 266  Available
#
# [267 rows x 20 columns]

# %%
merged_data['deal_satisfaction'] = merged_data['deal_satisfaction'].astype(float)
merged_data.loc[merged_data['deal_satisfaction'].isnull(), 'deal_satisfaction'] = np.nan

# %%
merged_data
# Out:
#     customerid      entity        name   surname birth_date   sex country  \
# 0        C0028  Individual     Madalyn    Mercer 1986-06-21     F     USA
# 1        C0027  Individual        Lara  Carrillo 1983-02-24     F     USA
# 2        C0112  Individual     Donavan   Flowers 1985-12-27     M     USA
# 3        C0160  Individual      Darien    Dorsey 1985-12-27     M     USA
# 4        C0014  Individual  Alessandra     Perry 1979-05-15     F     USA
# ..         ...         ...         ...       ...        ...   ...     ...
# 262        nan        None        None      None        NaT  None    None
# 263        nan        None        None      None        NaT  None    None
# 264        nan        None        None      None        NaT  None    None
# 265        nan        None        None      None        NaT  None    None
# 266        nan        None        None      None        NaT  None    None
#
#           state     purpose  deal_satisfaction mortgage   source   ﻿id  \
# 0    California        Home                5.0       No  Website  1030
# 1    California        Home                5.0       No  Website  1029
# 2    California        Home                1.0      Yes   Client  2002
# 3    California  Investment                3.0      Yes  Website  2031
# 4    California        Home                4.0       No   Agency  1049
# ..          ...         ...                ...      ...      ...   ...
# 262        None        None                NaN     None     None  5044
# 263        None        None                NaN     None     None  5047
# 264        None        None                NaN     None     None  5048
# 265        None        None                NaN     None     None  5050
# 266        None        None                NaN     None     None  5051
#
#      building  date_sale       type  property#     area         price  \
# 0           1 2005-11-01  Apartment         30   743.09  $246,172.68
# 1           1 2005-10-01  Apartment         29   756.21  $246,331.90
# 2           2 2007-07-01  Apartment          2   587.28  $209,280.91
# 3           2 2007-12-01  Apartment         31  1604.75  $452,667.01
# 4           1 2004-11-01  Apartment         49  1375.45  $467,083.31
# ..        ...        ...        ...        ...      ...           ...
# 262         5        NaT  Apartment         44  1238.58  $322,610.74
# 263         5        NaT  Apartment         47   794.52  $279,191.26
# 264         5        NaT  Apartment         48  1013.27  $287,996.53
# 265         5        NaT  Apartment         50  1074.71  $365,868.78
# 266         5        NaT  Apartment         51   789.25  $199,216.40
#
#         status
# 0        Sold
# 1        Sold
# 2        Sold
# 3        Sold
# 4        Sold
# ..         ...
# 262  Available
# 263  Available
# 264  Available
# 265  Available
# 266  Available
#
# [267 rows x 20 columns]

# %%
merged_data.loc[merged_data['customerid'] == 'nan', 'customerid'] = None

# %%
merged_data
# Out:
#     customerid      entity        name   surname birth_date   sex country  \
# 0        C0028  Individual     Madalyn    Mercer 1986-06-21     F     USA
# 1        C0027  Individual        Lara  Carrillo 1983-02-24     F     USA
# 2        C0112  Individual     Donavan   Flowers 1985-12-27     M     USA
# 3        C0160  Individual      Darien    Dorsey 1985-12-27     M     USA
# 4        C0014  Individual  Alessandra     Perry 1979-05-15     F     USA
# ..         ...         ...         ...       ...        ...   ...     ...
# 262       None        None        None      None        NaT  None    None
# 263       None        None        None      None        NaT  None    None
# 264       None        None        None      None        NaT  None    None
# 265       None        None        None      None        NaT  None    None
# 266       None        None        None      None        NaT  None    None
#
#           state     purpose  deal_satisfaction mortgage   source   ﻿id  \
# 0    California        Home                5.0       No  Website  1030
# 1    California        Home                5.0       No  Website  1029
# 2    California        Home                1.0      Yes   Client  2002
# 3    California  Investment                3.0      Yes  Website  2031
# 4    California        Home                4.0       No   Agency  1049
# ..          ...         ...                ...      ...      ...   ...
# 262        None        None                NaN     None     None  5044
# 263        None        None                NaN     None     None  5047
# 264        None        None                NaN     None     None  5048
# 265        None        None                NaN     None     None  5050
# 266        None        None                NaN     None     None  5051
#
#      building  date_sale       type  property#     area         price  \
# 0           1 2005-11-01  Apartment         30   743.09  $246,172.68
# 1           1 2005-10-01  Apartment         29   756.21  $246,331.90
# 2           2 2007-07-01  Apartment          2   587.28  $209,280.91
# 3           2 2007-12-01  Apartment         31  1604.75  $452,667.01
# 4           1 2004-11-01  Apartment         49  1375.45  $467,083.31
# ..        ...        ...        ...        ...      ...           ...
# 262         5        NaT  Apartment         44  1238.58  $322,610.74
# 263         5        NaT  Apartment         47   794.52  $279,191.26
# 264         5        NaT  Apartment         48  1013.27  $287,996.53
# 265         5        NaT  Apartment         50  1074.71  $365,868.78
# 266         5        NaT  Apartment         51   789.25  $199,216.40
#
#         status
# 0        Sold
# 1        Sold
# 2        Sold
# 3        Sold
# 4        Sold
# ..         ...
# 262  Available
# 263  Available
# 264  Available
# 265  Available
# 266  Available
#
# [267 rows x 20 columns]

# %%
merged_data.dtypes
# Out:
# customerid                   object
# entity                       object
# name                         object
# surname                      object
# birth_date           datetime64[ns]
# sex                          object
# country                      object
# state                        object
# purpose                      object
# deal_satisfaction           float64
# mortgage                     object
# source                       object
# ﻿id                           int64
# building                      int64
# date_sale            datetime64[ns]
# type                         object
# property#                     int64
# area                        float64
# price                        object
# status                       object
# dtype: object

# %%
# fixing the price column and changing it's data type to float
merged_data['price'] = merged_data['price'].str.replace(r'[$,]', '', regex = True).astype(float)

# %%
merged_data.dtypes
# Out:
# customerid                   object
# entity                       object
# name                         object
# surname                      object
# birth_date           datetime64[ns]
# sex                          object
# country                      object
# state                        object
# purpose                      object
# deal_satisfaction           float64
# mortgage                     object
# source                       object
# ﻿id                           int64
# building                      int64
# date_sale            datetime64[ns]
# type                         object
# property#                     int64
# area                        float64
# price                       float64
# status                       object
# dtype: object

# %%
merged_data
# Out:
#     customerid      entity        name   surname birth_date   sex country  \
# 0        C0028  Individual     Madalyn    Mercer 1986-06-21     F     USA
# 1        C0027  Individual        Lara  Carrillo 1983-02-24     F     USA
# 2        C0112  Individual     Donavan   Flowers 1985-12-27     M     USA
# 3        C0160  Individual      Darien    Dorsey 1985-12-27     M     USA
# 4        C0014  Individual  Alessandra     Perry 1979-05-15     F     USA
# ..         ...         ...         ...       ...        ...   ...     ...
# 262       None        None        None      None        NaT  None    None
# 263       None        None        None      None        NaT  None    None
# 264       None        None        None      None        NaT  None    None
# 265       None        None        None      None        NaT  None    None
# 266       None        None        None      None        NaT  None    None
#
#           state     purpose  deal_satisfaction mortgage   source   ﻿id  \
# 0    California        Home                5.0       No  Website  1030
# 1    California        Home                5.0       No  Website  1029
# 2    California        Home                1.0      Yes   Client  2002
# 3    California  Investment                3.0      Yes  Website  2031
# 4    California        Home                4.0       No   Agency  1049
# ..          ...         ...                ...      ...      ...   ...
# 262        None        None                NaN     None     None  5044
# 263        None        None                NaN     None     None  5047
# 264        None        None                NaN     None     None  5048
# 265        None        None                NaN     None     None  5050
# 266        None        None                NaN     None     None  5051
#
#      building  date_sale       type  property#     area      price     status
# 0           1 2005-11-01  Apartment         30   743.09  246172.68      Sold
# 1           1 2005-10-01  Apartment         29   756.21  246331.90      Sold
# 2           2 2007-07-01  Apartment          2   587.28  209280.91      Sold
# 3           2 2007-12-01  Apartment         31  1604.75  452667.01      Sold
# 4           1 2004-11-01  Apartment         49  1375.45  467083.31      Sold
# ..        ...        ...        ...        ...      ...        ...        ...
# 262         5        NaT  Apartment         44  1238.58  322610.74  Available
# 263         5        NaT  Apartment         47   794.52  279191.26  Available
# 264         5        NaT  Apartment         48  1013.27  287996.53  Available
# 265         5        NaT  Apartment         50  1074.71  365868.78  Available
# 266         5        NaT  Apartment         51   789.25  199216.40  Available
#
# [267 rows x 20 columns]

# %%
merged_data['country'].unique()
# Out:
# array(['USA', 'UK', 'USA ', 'Belgium', 'Russia', 'Denmark', 'Germany',
#        'Mexico', 'Canada', None], dtype=object)

# %%
#fixing the inconsistency in the 'country' column
merged_data['country'] = merged_data['country'].str.strip()
merged_data['country'].unique()
# Out:
# array(['USA', 'UK', 'Belgium', 'Russia', 'Denmark', 'Germany', 'Mexico',
#        'Canada', None], dtype=object)

# %%
merged_data['state'].unique()
# Out:
# array(['California', 'Virginia', 'Arizona', 'Oregon', 'Nevada',
#        'Colorado', 'Utah', None, 'Kansas', 'Wyoming'], dtype=object)

# %%
# Converting the mortgage column from categorical to numeric
merged_data.loc[merged_data['mortgage'] == 'Yes', 'mortgage'] = 1
merged_data.loc[merged_data['mortgage'] == 'No', 'mortgage'] = 0
merged_data
# Out:
#     customerid      entity        name   surname birth_date   sex country  \
# 0        C0028  Individual     Madalyn    Mercer 1986-06-21     F     USA
# 1        C0027  Individual        Lara  Carrillo 1983-02-24     F     USA
# 2        C0112  Individual     Donavan   Flowers 1985-12-27     M     USA
# 3        C0160  Individual      Darien    Dorsey 1985-12-27     M     USA
# 4        C0014  Individual  Alessandra     Perry 1979-05-15     F     USA
# ..         ...         ...         ...       ...        ...   ...     ...
# 262       None        None        None      None        NaT  None    None
# 263       None        None        None      None        NaT  None    None
# 264       None        None        None      None        NaT  None    None
# 265       None        None        None      None        NaT  None    None
# 266       None        None        None      None        NaT  None    None
#
#           state     purpose  deal_satisfaction mortgage   source   ﻿id  \
# 0    California        Home                5.0        0  Website  1030
# 1    California        Home                5.0        0  Website  1029
# 2    California        Home                1.0        1   Client  2002
# 3    California  Investment                3.0        1  Website  2031
# 4    California        Home                4.0        0   Agency  1049
# ..          ...         ...                ...      ...      ...   ...
# 262        None        None                NaN     None     None  5044
# 263        None        None                NaN     None     None  5047
# 264        None        None                NaN     None     None  5048
# 265        None        None                NaN     None     None  5050
# 266        None        None                NaN     None     None  5051
#
#      building  date_sale       type  property#     area      price     status
# 0           1 2005-11-01  Apartment         30   743.09  246172.68      Sold
# 1           1 2005-10-01  Apartment         29   756.21  246331.90      Sold
# 2           2 2007-07-01  Apartment          2   587.28  209280.91      Sold
# 3           2 2007-12-01  Apartment         31  1604.75  452667.01      Sold
# 4           1 2004-11-01  Apartment         49  1375.45  467083.31      Sold
# ..        ...        ...        ...        ...      ...        ...        ...
# 262         5        NaT  Apartment         44  1238.58  322610.74  Available
# 263         5        NaT  Apartment         47   794.52  279191.26  Available
# 264         5        NaT  Apartment         48  1013.27  287996.53  Available
# 265         5        NaT  Apartment         50  1074.71  365868.78  Available
# 266         5        NaT  Apartment         51   789.25  199216.40  Available
#
# [267 rows x 20 columns]

# %%
# combining name + surname = Full name
merged_data['full_name'] = merged_data['name'] + ' ' + merged_data['surname']
merged_data.drop('name', axis = 1, inplace = True)
merged_data.drop('surname', axis = 1, inplace = True)
merged_data
# Out:
#     customerid      entity birth_date   sex country       state     purpose  \
# 0        C0028  Individual 1986-06-21     F     USA  California        Home
# 1        C0027  Individual 1983-02-24     F     USA  California        Home
# 2        C0112  Individual 1985-12-27     M     USA  California        Home
# 3        C0160  Individual 1985-12-27     M     USA  California  Investment
# 4        C0014  Individual 1979-05-15     F     USA  California        Home
# ..         ...         ...        ...   ...     ...         ...         ...
# 262       None        None        NaT  None    None        None        None
# 263       None        None        NaT  None    None        None        None
# 264       None        None        NaT  None    None        None        None
# 265       None        None        NaT  None    None        None        None
# 266       None        None        NaT  None    None        None        None
#
#      deal_satisfaction mortgage   source   ﻿id  building  date_sale  \
# 0                  5.0        0  Website  1030         1 2005-11-01
# 1                  5.0        0  Website  1029         1 2005-10-01
# 2                  1.0        1   Client  2002         2 2007-07-01
# 3                  3.0        1  Website  2031         2 2007-12-01
# 4                  4.0        0   Agency  1049         1 2004-11-01
# ..                 ...      ...      ...   ...       ...        ...
# 262                NaN     None     None  5044         5        NaT
# 263                NaN     None     None  5047         5        NaT
# 264                NaN     None     None  5048         5        NaT
# 265                NaN     None     None  5050         5        NaT
# 266                NaN     None     None  5051         5        NaT
#
#           type  property#     area      price     status         full_name
# 0    Apartment         30   743.09  246172.68      Sold     Madalyn Mercer
# 1    Apartment         29   756.21  246331.90      Sold      Lara Carrillo
# 2    Apartment          2   587.28  209280.91      Sold    Donavan Flowers
# 3    Apartment         31  1604.75  452667.01      Sold      Darien Dorsey
# 4    Apartment         49  1375.45  467083.31      Sold   Alessandra Perry
# ..         ...        ...      ...        ...        ...               ...
# 262  Apartment         44  1238.58  322610.74  Available               NaN
# 263  Apartment         47   794.52  279191.26  Available               NaN
# 264  Apartment         48  1013.27  287996.53  Available               NaN
# 265  Apartment         50  1074.71  365868.78  Available               NaN
# 266  Apartment         51   789.25  199216.40  Available               NaN
#
# [267 rows x 19 columns]

# %%
# Handling missing name values
merged_data.loc[merged_data['full_name'].isnull(), 'full_name'] = None
merged_data
# Out:
#     customerid      entity birth_date   sex country       state     purpose  \
# 0        C0028  Individual 1986-06-21     F     USA  California        Home
# 1        C0027  Individual 1983-02-24     F     USA  California        Home
# 2        C0112  Individual 1985-12-27     M     USA  California        Home
# 3        C0160  Individual 1985-12-27     M     USA  California  Investment
# 4        C0014  Individual 1979-05-15     F     USA  California        Home
# ..         ...         ...        ...   ...     ...         ...         ...
# 262       None        None        NaT  None    None        None        None
# 263       None        None        NaT  None    None        None        None
# 264       None        None        NaT  None    None        None        None
# 265       None        None        NaT  None    None        None        None
# 266       None        None        NaT  None    None        None        None
#
#      deal_satisfaction mortgage   source   ﻿id  building  date_sale  \
# 0                  5.0        0  Website  1030         1 2005-11-01
# 1                  5.0        0  Website  1029         1 2005-10-01
# 2                  1.0        1   Client  2002         2 2007-07-01
# 3                  3.0        1  Website  2031         2 2007-12-01
# 4                  4.0        0   Agency  1049         1 2004-11-01
# ..                 ...      ...      ...   ...       ...        ...
# 262                NaN     None     None  5044         5        NaT
# 263                NaN     None     None  5047         5        NaT
# 264                NaN     None     None  5048         5        NaT
# 265                NaN     None     None  5050         5        NaT
# 266                NaN     None     None  5051         5        NaT
#
#           type  property#     area      price     status         full_name
# 0    Apartment         30   743.09  246172.68      Sold     Madalyn Mercer
# 1    Apartment         29   756.21  246331.90      Sold      Lara Carrillo
# 2    Apartment          2   587.28  209280.91      Sold    Donavan Flowers
# 3    Apartment         31  1604.75  452667.01      Sold      Darien Dorsey
# 4    Apartment         49  1375.45  467083.31      Sold   Alessandra Perry
# ..         ...        ...      ...        ...        ...               ...
# 262  Apartment         44  1238.58  322610.74  Available              None
# 263  Apartment         47   794.52  279191.26  Available              None
# 264  Apartment         48  1013.27  287996.53  Available              None
# 265  Apartment         50  1074.71  365868.78  Available              None
# 266  Apartment         51   789.25  199216.40  Available              None
#
# [267 rows x 19 columns]

# %%
# creating an age column instead of the birthdate column
current_dt = datetime.datetime.now()
merged_data['age'] = (current_dt - merged_data['birth_date']).dt.days // 365
merged_data.drop('birth_date', axis = 1, inplace = True)
merged_data
# Out:
#     customerid      entity   sex country       state     purpose  \
# 0        C0028  Individual     F     USA  California        Home
# 1        C0027  Individual     F     USA  California        Home
# 2        C0112  Individual     M     USA  California        Home
# 3        C0160  Individual     M     USA  California  Investment
# 4        C0014  Individual     F     USA  California        Home
# ..         ...         ...   ...     ...         ...         ...
# 262       None        None  None    None        None        None
# 263       None        None  None    None        None        None
# 264       None        None  None    None        None        None
# 265       None        None  None    None        None        None
# 266       None        None  None    None        None        None
#
#      deal_satisfaction mortgage   source   ﻿id  building  date_sale  \
# 0                  5.0        0  Website  1030         1 2005-11-01
# 1                  5.0        0  Website  1029         1 2005-10-01
# 2                  1.0        1   Client  2002         2 2007-07-01
# 3                  3.0        1  Website  2031         2 2007-12-01
# 4                  4.0        0   Agency  1049         1 2004-11-01
# ..                 ...      ...      ...   ...       ...        ...
# 262                NaN     None     None  5044         5        NaT
# 263                NaN     None     None  5047         5        NaT
# 264                NaN     None     None  5048         5        NaT
# 265                NaN     None     None  5050         5        NaT
# 266                NaN     None     None  5051         5        NaT
#
#           type  property#     area      price     status         full_name  \
# 0    Apartment         30   743.09  246172.68      Sold     Madalyn Mercer
# 1    Apartment         29   756.21  246331.90      Sold      Lara Carrillo
# 2    Apartment          2   587.28  209280.91      Sold    Donavan Flowers
# 3    Apartment         31  1604.75  452667.01      Sold      Darien Dorsey
# 4    Apartment         49  1375.45  467083.31      Sold   Alessandra Perry
# ..         ...        ...      ...        ...        ...               ...
# 262  Apartment         44  1238.58  322610.74  Available              None
# 263  Apartment         47   794.52  279191.26  Available              None
# 264  Apartment         48  1013.27  287996.53  Available              None
# 265  Apartment         50  1074.71  365868.78  Available              None
# 266  Apartment         51   789.25  199216.40  Available              None
#
#       age
# 0    39.0
# 1    42.0
# 2    39.0
# 3    39.0
# 4    46.0
# ..    ...
# 262   NaN
# 263   NaN
# 264   NaN
# 265   NaN
# 266   NaN
#
# [267 rows x 19 columns]

# %% [markdown]
# ## Descriptive Statistics

# %%
merged_data.describe()
# Out:
#        deal_satisfaction          ﻿id    building  \
# count         195.000000   267.000000  267.000000
# mean            3.600000  2975.142322    2.947566
# min             1.000000  1002.000000    1.000000
# 25%             3.000000  2015.500000    2.000000
# 50%             4.000000  3024.000000    3.000000
# 75%             5.000000  4031.500000    4.000000
# max             5.000000  5052.000000    5.000000
# std             1.340872  1392.197474    1.391794
#
#                            date_sale   property#         area          price  \
# count                            195  267.000000   267.000000     267.000000
# mean   2006-11-08 14:38:46.153846272   27.580524   936.221311  281171.901386
# min              2004-03-01 00:00:00    1.000000   410.710000  117564.070000
# 25%              2006-04-16 00:00:00   14.500000   756.210000  217553.055000
# 50%              2007-03-01 00:00:00   28.000000   798.280000  249075.660000
# 75%              2007-09-01 00:00:00   40.000000  1121.950000  326964.855000
# max              2010-05-01 00:00:00   59.000000  1942.500000  538271.740000
# std                              NaN   15.361437   284.894858   89119.121005
#
#               age
# count  178.000000
# mean    64.000000
# min     39.000000
# 25%     54.250000
# 50%     62.000000
# 75%     73.750000
# max     94.000000
# std     12.990653

# %%
merged_data['building'].value_counts()
# Out:
# building
# 3    63
# 2    57
# 1    52
# 5    52
# 4    43
# Name: count, dtype: int64

# %%
# number of (sold vs available) properties per property type
merged_data.groupby(['building', 'status'])['status'].count()
# Out:
# building  status
# 1          Sold        46
#           Available     6
# 2          Sold        54
#           Available     3
# 3          Sold        53
#           Available    10
# 4          Sold        23
#           Available    20
# 5          Sold        19
#           Available    33
# Name: status, dtype: int64

# %%
merged_data.groupby(['building', 'source'])['status'].count()
# Out:
# building  source
# 1         Agency      8
#           Website    38
# 2         Agency     24
#           Client      7
#           Website    23
# 3         Agency     19
#           Client      8
#           Website    26
# 4         Agency      4
#           Client      1
#           Website    18
# 5         Agency      4
#           Client      1
#           Website    14
# Name: status, dtype: int64

# %%
merged_data.groupby(['building', 'purpose'])['status'].count()
# Out:
# building  purpose
# 1         Home          27
#           Investment    19
# 2         Home          34
#           Investment    20
# 3         Home          29
#           Investment    24
# 4         Home          20
#           Investment     3
# 5         Home           9
#           Investment    10
# Name: status, dtype: int64

# %%
merged_data.groupby(['building', 'sex'])['sex'].count()
# Out:
# building  sex
# 1         F      13
#           M      18
# 2         F      20
#           M      32
# 3         F      17
#           M      36
# 4         F      13
#           M      10
# 5         F       7
#           M      12
# Name: sex, dtype: int64

# %%
merged_data.groupby(['building', 'type'])['type'].count()
# Out:
# building  type
# 1         Apartment    44
#           Office        8
# 2         Apartment    57
# 3         Apartment    63
# 4         Apartment    43
# 5         Apartment    52
# Name: type, dtype: int64

# %%
merged_data.groupby(['building', 'entity'])['entity'].count()
# Out:
# building  entity
# 1         Company       15
#           Individual    31
# 2         Company        2
#           Individual    52
# 3         Individual    53
# 4         Individual    23
# 5         Individual    19
# Name: entity, dtype: int64

# %%
merged_data.groupby(['building'])[['deal_satisfaction', 'area', 'price', 'age', 'mortgage']].agg(['count', 'mean', 'median']).transpose()
# Out:
# building                            1              2              3  \
# deal_satisfaction count            46             54             53
#                   mean       3.630435       3.518519       3.566038
#                   median          5.0            4.0            4.0
# area              count            52             57             63
#                   mean     928.038846      943.89193     927.852381
#                   median       782.25         785.48         781.07
# price             count            52             57             63
#                   mean    275143.2425  286661.848246  280451.255556
#                   median   241983.225      250773.15      252185.99
# age               count            31             52             53
#                   mean      63.741935      61.846154      66.207547
#                   median         62.0           60.0           65.0
# mortgage          count            46             54             53
#                   mean       0.304348       0.333333       0.283019
#                   median          0.0            0.0            0.0
#
# building                              4              5
# deal_satisfaction count              23             19
#                   mean         3.869565       3.526316
#                   median            4.0            4.0
# area              count              43             52
#                   mean        974.72093     914.298654
#                   median         794.52          798.5
# price             count              43             52
#                   mean    290239.515581  274557.604615
#                   median      244820.67      262433.08
# age               count              23             19
#                   mean        62.434783      66.052632
#                   median           60.0           66.0
# mortgage          count              23             19
#                   mean         0.391304       0.315789
#                   median            0.0            0.0

# %%
# number of sold properites per country
merged_data.groupby(['country'])['status'].count()
# Out:
# country
# Belgium      2
# Canada       7
# Denmark      1
# Germany      1
# Mexico       1
# Russia       4
# UK           2
# USA        177
# Name: status, dtype: int64

# %%
merged_data.groupby(['country', 'source'])['status'].count()
# Out:
# country  source
# Belgium  Agency       1
#          Website      1
# Canada   Website      7
# Denmark  Agency       1
# Germany  Agency       1
# Mexico   Agency       1
# Russia   Agency       3
#          Website      1
# UK       Agency       2
# USA      Agency      50
#          Client      17
#          Website    110
# Name: status, dtype: int64

# %%
merged_data.groupby(['country', 'sex'])['sex'].count()
# Out:
# country  sex
# Belgium  F       1
#          M       1
# Canada   M       7
# Denmark  F       1
# Germany  M       1
# Mexico   M       1
# Russia   F       3
#          M       1
# UK       M       2
# USA      F      65
#          M      95
# Name: sex, dtype: int64

# %%
merged_data.groupby(['country', 'entity'])['entity'].count()
# Out:
# country  entity
# Belgium  Individual      2
# Canada   Individual      7
# Denmark  Individual      1
# Germany  Individual      1
# Mexico   Individual      1
# Russia   Individual      4
# UK       Individual      2
# USA      Company        17
#          Individual    160
# Name: entity, dtype: int64

# %%
merged_data.groupby(['country', 'purpose'])['purpose'].count()
# Out:
# country  purpose
# Belgium  Home            1
#          Investment      1
# Canada   Investment      7
# Denmark  Investment      1
# Germany  Investment      1
# Mexico   Home            1
# Russia   Home            2
#          Investment      2
# UK       Investment      2
# USA      Home          115
#          Investment     62
# Name: purpose, dtype: int64

# %%
merged_data.groupby(['country', 'type'])['type'].count()
# Out:
# country  type
# Belgium  Apartment      2
# Canada   Apartment      7
# Denmark  Apartment      1
# Germany  Apartment      1
# Mexico   Apartment      1
# Russia   Apartment      4
# UK       Apartment      2
# USA      Apartment    170
#          Office         7
# Name: type, dtype: int64

# %%
merged_data.groupby(['country'])[['deal_satisfaction', 'area', 'price', 'age', 'mortgage']].agg(['count', 'mean', 'median']).transpose()
# Out:
# country                     Belgium         Canada    Denmark    Germany  \
# deal_satisfaction count           2              7          1          1
#                   mean          3.0            5.0        1.0        5.0
#                   median        3.0            5.0        1.0        5.0
# area              count           2              7          1          1
#                   mean       852.73     917.382857     785.48     743.41
#                   median     852.73         785.48     785.48     743.41
# price             count           2              7          1          1
#                   mean    229075.47  274069.384286  257183.48  205098.21
#                   median  229075.47      236608.95  257183.48  205098.21
# age               count           2              7          1          1
#                   mean         63.0           78.0       60.0       58.0
#                   median       63.0           78.0       60.0       58.0
# mortgage          count           2              7          1          1
#                   mean          0.0            0.0        0.0        0.0
#                   median        0.0            0.0        0.0        0.0
#
# country                      Mexico      Russia         UK            USA
# deal_satisfaction count           1           4          2            177
#                   mean          3.0         2.5        4.0       3.581921
#                   median        3.0         3.0        4.0            4.0
# area              count           1           4          2            177
#                   mean      1283.45    903.7575     739.48     900.794463
#                   median    1283.45     927.455     739.48         794.52
# price             count           1           4          2            177
#                   mean    338181.18  278828.835  220142.68  270096.266554
#                   median  338181.18   275653.94  220142.68      243052.59
# age               count           1           4          2            160
#                   mean         60.0        74.0       55.5       63.34375
#                   median       60.0        72.5       55.5           62.0
# mortgage          count           1           4          2            177
#                   mean          0.0        0.25        0.0       0.344633
#                   median        0.0         0.0        0.0            0.0

# %%
merged_data.groupby(['state'])['status'].value_counts()
# Out:
# state       status
# Arizona     Sold       11
# California  Sold      120
# Colorado    Sold       11
# Kansas      Sold        1
# Nevada      Sold       17
# Oregon      Sold       11
# Utah        Sold        5
# Virginia    Sold        4
# Wyoming     Sold        1
# Name: count, dtype: int64

# %%
merged_data.groupby(['state'])['status'].value_counts().cumsum()
# Out:
# state       status
# Arizona     Sold       11
# California  Sold      131
# Colorado    Sold      142
# Kansas      Sold      143
# Nevada      Sold      160
# Oregon      Sold      171
# Utah        Sold      176
# Virginia    Sold      180
# Wyoming     Sold      181
# Name: count, dtype: int64

# %%
bins = [19, 25, 31, 36, 42, 48, 54, 59, 65, 71]
merged_data['age_intervals'] = pd.cut(merged_data['age'], bins = bins)
merged_data['age_intervals']
# Out:
# 0      (36.0, 42.0]
# 1      (36.0, 42.0]
# 2      (36.0, 42.0]
# 3      (36.0, 42.0]
# 4      (42.0, 48.0]
#            ...
# 262             NaN
# 263             NaN
# 264             NaN
# 265             NaN
# 266             NaN
# Name: age_intervals, Length: 267, dtype: category
# Categories (9, interval[int64, right]): [(19, 25] < (25, 31] < (31, 36] < (36, 42] ... (48, 54] < (54, 59] < (59, 65] < (65, 71]]

# %%
merged_data['price_intervals'] = pd.cut(merged_data['price'], 10)
merged_data.groupby('price_intervals')['status'].count()
# Out:
# E:\ALL\Temp\Temp\ipykernel_16984\1716237191.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   merged_data.groupby('price_intervals')['status'].count()
# price_intervals
# (117143.362, 159634.837]     3
# (159634.837, 201705.604]    32
# (201705.604, 243776.371]    88
# (243776.371, 285847.138]    47
# (285847.138, 327917.905]    31
# (327917.905, 369988.672]    18
# (369988.672, 412059.439]    21
# (412059.439, 454130.206]     7
# (454130.206, 496200.973]    11
# (496200.973, 538271.74]      9
# Name: status, dtype: int64

# %%
merged_data['age'].corr(merged_data['price'])
# Out:
# -0.1671522528654237

# %%
merged_data['age'].cov(merged_data['price'])
# Out:
# -170510.84265536722

# %%
avg_satisfaction_rate_per_country = merged_data.groupby('country')['deal_satisfaction'].mean()
avg_satisfaction_rate_per_country.plot(kind = 'bar')
plt.show()

# %%
avg_satisfaction_rate_per_state = merged_data.groupby('state')['deal_satisfaction'].mean()
avg_satisfaction_rate_per_state.plot(kind = 'bar')
plt.show()
